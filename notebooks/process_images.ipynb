# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/MLHC/satellite_semantic_segmentation/src
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/MLHC/satellite_semantic_segmentation/src

# %%
from image_processing import process_images

# %%
imgs = [
    "image_50001_2016-01-10", "image_50001_2016-03-06", "image_50001_2017-07-23", "image_50001_2017-08-13",
    "image_54001_2016-02-07", "image_54001_2018-02-18", "image_76001_2018-02-25", "image_5001_2018-02-11",
    "image_73001_2018-03-04", "image_5001_2016-06-05"
]

# %%
for img in imgs:
    process_images(img)
